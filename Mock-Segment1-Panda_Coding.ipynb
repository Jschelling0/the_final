# %%
import pandas as pd

# %%
cities_temp = pd.read_csv('../Climate/AverageTemperatureofCities.csv')

# %%
cities_temp
# Out:
#        Country         City           Jan           Feb           Mar  \
# 0      Algeria      Algiers  11.2\n(52.2)  11.9\n(53.4)  12.8\n(55.0)
# 1      Algeria  Tamanrasset  12.8\n(55.0)  15.0\n(59.0)  18.1\n(64.6)
# 2      Algeria      Reggane  16.0\n(60.8)  18.2\n(64.8)  23.1\n(73.6)
# 3       Angola       Luanda  26.7\n(80.1)  28.5\n(83.3)  28.6\n(83.5)
# 4        Benin      Cotonou  27.3\n(81.1)  28.5\n(83.3)  28.9\n(84.0)
# ..         ...          ...           ...           ...           ...
# 446       Peru         Lima  22.1\n(71.8)  22.7\n(72.9)  22.2\n(72.0)
# 447       Peru        Piura  26.8\n(80.2)  27.8\n(82.0)  27.8\n(82.0)
# 448   Suriname   Paramaribo  26.0\n(78.8)  26.0\n(78.8)  26.2\n(79.2)
# 449    Uruguay   Montevideo  23.0\n(73.4)  22.5\n(72.5)  20.6\n(69.1)
# 450  Venezuela      Caracas  20.2\n(68.4)  20.8\n(69.4)  21.7\n(71.1)
#
#               Apr           May           Jun            Jul            Aug  \
# ...

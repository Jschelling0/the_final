# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

import matplotlib.pyplot as plt
from datetime import datetime

import gmaps
import requests

# %%
pip install config
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
city_data_df = pd.read_csv("./Resources/Average Temperature of Cities.csv")
city_data_df.head(10)
# Out:
#     Country         City           Jan           Feb           Mar  \
# 0   Algeria      Algiers  11.2\n(52.2)  11.9\n(53.4)  12.8\n(55.0)
# 1   Algeria  Tamanrasset  12.8\n(55.0)  15.0\n(59.0)  18.1\n(64.6)
# 2   Algeria      Reggane  16.0\n(60.8)  18.2\n(64.8)  23.1\n(73.6)
# 3    Angola       Luanda  26.7\n(80.1)  28.5\n(83.3)  28.6\n(83.5)
# 4     Benin      Cotonou  27.3\n(81.1)  28.5\n(83.3)  28.9\n(84.0)
# 5     Benin      Parakou  26.5\n(79.7)  28.7\n(83.7)  29.6\n(85.3)
# 6     Benin        Kandi  24.9\n(76.8)  27.8\n(82.0)  30.9\n(87.6)
# 7  Botswana         Maun  25.4\n(77.7)  25.1\n(77.2)  24.2\n(75.6)
# 8  Botswana     Gaborone      26\n(79)      25\n(77)      24\n(75)
# 9  Botswana       Ghanzi  25.9\n(78.6)  25.3\n(77.5)  24.1\n(75.4)
#
#             Apr           May           Jun            Jul            Aug  \
# 0  14.7\n(58.5)  17.7\n(63.9)  21.3\n(70.3)   24.6\n(76.3)   25.2\n(77.4)
# 1  22.2\n(72.0)  26.1\n(79.0)  28.9\n(84.0)   28.7\n(83.7)   28.2\n(82.8)
# ...
